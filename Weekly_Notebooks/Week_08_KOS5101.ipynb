# %% [markdown]
# # Week 8: 중간 시험
# ## 학습 목표전반부 내용 평가.

# %% [markdown]
# ## 데이터 시뮬레이션 (Data Simulation)Python을 사용하여 가상의 데이터를 생성합니다.

# %%
# 중간고사 기간입니다. # 그동안 학습한 Python, Basic Statistics, CTT 내용을 복습하세요.
